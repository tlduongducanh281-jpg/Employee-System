# %% [markdown]
# <a href="https://colab.research.google.com/github/tlduongducanh281-jpg/Employee-System/blob/main/midterm_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("data/store_sales/train.csv")
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date").sort_index()
print(df.head())
# Out:
#             id  store_nbr      family  sales  onpromotion
# date
# 2013-01-01   0          1  AUTOMOTIVE    0.0            0
# 2013-01-01   1          1   BABY CARE    0.0            0
# 2013-01-01   2          1      BEAUTY    0.0            0
# 2013-01-01   3          1   BEVERAGES    0.0            0
# 2013-01-01   4          1       BOOKS    0.0            0
